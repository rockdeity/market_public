# %%
import glob

pickle_files = glob.glob('**/*.pkl', recursive=True)
print(f"There are {len(pickle_files)} pickle files in this project.")
# Out:
# There are 3703 pickle files in this project.

# %%
import glob

pickle_files = glob.glob('**/*.pkl', recursive=True)
print(f"There are {len(pickle_files)} pickle files in this project.")
# Out:
# There are 8054 pickle files in this project.

# %%
import pickle

with open('data/grade_ADP.pkl', 'rb') as f:
    data = pickle.load(f)
    display(data.ffill())
# Out:
# combined_name      gradingCompany_newGrade_Argus  \
# symbol date
# ADP    2012-03-01                            NaN
#        2012-05-01                            NaN
#        2012-05-24                            NaN
#        2012-05-25                            NaN
#        2012-06-24                            NaN
# ...                                          ...
#        2022-05-01                            1.0
#        2022-07-19                            1.0
#        2022-07-31                            1.0
#        2023-01-25                            1.0
#        2023-04-26                            1.0
#
# combined_name      gradingCompany_newGrade_Argus_Research  \
# symbol date
# ADP    2012-03-01                                     NaN
#        2012-05-01                                     NaN
#        2012-05-24                                     NaN
#        2012-05-25                                     NaN
# ...

# %%
import os
import glob

# Get a list of all dividend pickle files
# dividend_pickle_files = glob.glob('**/*dividend*.pkl', recursive=True)
pickle_files = glob.glob('data/*.pkl')

# Iterate over the list of files and remove each one
for file_name in pickle_files:
    os.remove(file_name)

# %%
import os
import glob

# Get a list of all dividend pickle files
yfin_files = glob.glob(os.path.join(os.getcwd(), 'yfin*.csv'), recursive=False)

# Iterate over the list of files and remove each one
for file_name in yfin_files:
    os.remove(file_name)

# %%
# %pip install ib_insync

from ib_insync import IB

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=1)
print(ib.isConnected())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 6
#       3 from ib_insync import IB
#       5 ib = IB()
# ----> 6 ib.connect('127.0.0.1', 7496, clientId=1)
#       7 print(ib.isConnected())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ib_insync\ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
# ...

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/73.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/73.0 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/73.0 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 73.0/73.0 kB 667.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
